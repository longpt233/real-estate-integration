# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/home/darkknight/real-estate-integration/prj-exam/schema-matching/data.csv', encoding='utf-8')
data = data.drop(["Unnamed: 0"], axis=1)
data
# Out:
# /tmp/ipykernel_16088/4019081916.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/home/darkknight/real-estate-integration/prj-exam/schema-matching/data.csv', encoding='utf-8')
#                                                    title  \
# 0        Bán nhà 2C Lê Phụng Hiểu, Tràng Tiền, Hoàn Kiếm
# 1                    Cần bán 2 căn studio 36m2 giá 750tr
# 2      Chính chủ bán hoặc Cho thuê CHCC Him Lam, Quận...
# 3      MUA NGAY KẺO TIẾC:CĂN HỘ CAO CẤP VEN BIỂN NHA ...
# 4      Mở bán đợt cuối dự án Tecco Diamond Thanh Trì ...
# ...                                                  ...
# 39814            Căn hộ chung cư tại Hoàng Huy Commerce
# 39815  CĐT BÁN CẮT LỖ 100TR QUỸ CĂN NGOẠI GIAO 2-3PN ...
# 39816  CẮT LỖ CĂN 3PN 2VS GIÁ 2,57 TỶ, 2N 1VS GIÁ 1,7...
# 39817  BÁN CĂN HỘ CHUNG CƯ 1,5PN = 46,3M2 TẠI VINHOME...
# 39818  SỞ HỮU CĂN HỘ CAO CẤP TIÊU CHUẨN 5 SAO TRÊN MẶ...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39819 entries, 0 to 39818
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          39819 non-null  object
#  1   description    36898 non-null  object
#  2   price          38636 non-null  float64
#  3   square         39819 non-null  float64
#  4   type           39819 non-null  object
#  5   name_contact   38219 non-null  object
#  6   phone_contact  38219 non-null  object
#  7   date           39819 non-null  object
#  8   direct         12134 non-null  object
#  9   address        39819 non-null  object
#  10  floor          21427 non-null  object
#  11  bedroom        31711 non-null  object
#  12  link_image     39807 non-null  object
#  13  url_page       39819 non-null  object
#  14  juridical      14623 non-null  object
#  15  length         21592 non-null  float64
#  16  width          21592 non-null  float64
# ...

# %%
# %cd /home/darkknight/real-estate-integration/prj-exam/data-matching/lib-match
# Out:
# /home/darkknight/real-estate-integration/prj-exam/data-matching/lib-match

# %%
data["description"].fillna('None', inplace=True)
data["description"]
# Out:
# 0                                   Chính chủ cần bán nhà:
# 1        Cần bán 2 căn studio 36m2 giá 750tr,Vị Trí : K...
# 2        Chính chủ bán hoặc Cho thuê CHCC Him Lam, Quận...
# 3        MUA NGAY KẺO TIẾC:CĂN HỘ CAO CẤP VEN BIỂN NHA ...
# 4                                                     None
#                                ...
# 39814    Cơ hội cuối cùng sở hữu căn hộ Hoàng Huy Comme...
# 39815                                                 None
# 39816                                                 None
# 39817                                                 None
# 39818                                                 None
# Name: description, Length: 39819, dtype: object

# %%
# !python train_remove_duplicate.py
# Out:
# /home/darkknight/real-estate-integration/prj-exam/data-matching/lib-match/remove_duplicate.py:21: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path_data, encoding='utf-8')

# %%
# !python execute_remove_duplicate.py
# Out:
# execute_remove_duplicate.py:9: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path_data, encoding='utf-8')
# Original size 39819
# Traceback (most recent call last):
#   File "execute_remove_duplicate.py", line 15, in <module>
#     df = remover.remove_duplicate(df)
#   File "/home/darkknight/real-estate-integration/prj-exam/data-matching/lib-match/remove_duplicate.py", line 118, in remove_duplicate
#     df.set_index(["property_ward", "property_district",
#   File "/home/semendemon/anaconda3/envs/KALAPA/lib/python3.8/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/semendemon/anaconda3/envs/KALAPA/lib/python3.8/site-packages/pandas/core/frame.py", line 5488, in set_index
#     raise KeyError(f"None of {missing} are in the columns")
# ...
